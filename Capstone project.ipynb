# %% [markdown]
# # Section 1

# %% [markdown]
# ### download data

# %%
import requests
from bs4 import BeautifulSoup
headers = {
    'Access-Control-Allow-Origin': '*',
    'Access-Control-Allow-Methods': 'GET',
    'Access-Control-Allow-Headers': 'Content-Type',
    'Access-Control-Max-Age': '3600',
    'User-Agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0'
    }
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
req = requests.get(url, headers)
soup = BeautifulSoup(req.content, 'html.parser')

table_contents=[]
table=soup.find('table')
for row in table.findAll('td'):
    cell = {}
    if row.span.text=='Not assigned':
        pass
    else:
        cell['PostalCode'] = row.p.text[:3]
        cell['Borough'] = (row.span.text).split('(')[0]
        cell['Neighborhood'] = (((((row.span.text).split('(')[1]).strip(')')).replace(' /',',')).replace(')',' ')).strip(' ')
        table_contents.append(cell)

# %% [markdown]
# ### transform

# %%
import pandas as pd

df=pd.DataFrame(table_contents)
df['Borough']=df['Borough'].replace({'Downtown TorontoStn A PO Boxes25 The Esplanade':'Downtown Toronto Stn A',
                                             'East TorontoBusiness reply mail Processing Centre969 Eastern':'East Toronto Business',
                                             'EtobicokeNorthwest':'Etobicoke Northwest','East YorkEast Toronto':'East York/East Toronto',
                                             'MississaugaCanada Post Gateway Processing Centre':'Mississauga'})
df.shape
# Out:
# (103, 3)

# %% [markdown]
# # Section 2

# %%
#%pip install wget

# %%
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/labs_v1/Geospatial_Coordinates.csv"
Geospatial_Coordinates = pd.read_csv(url)

# %%
data = pd.merge(df, Geospatial_Coordinates, left_on='PostalCode', right_on='Postal Code', how='left').drop('Postal Code', axis=1)
data.head()
# Out:
#   PostalCode           Borough                      Neighborhood   Latitude  \
# 0        M3A        North York                         Parkwoods  43.753259
# 1        M4A        North York                  Victoria Village  43.725882
# 2        M5A  Downtown Toronto         Regent Park, Harbourfront  43.654260
# 3        M6A        North York  Lawrence Manor, Lawrence Heights  43.718518
# 4        M7A      Queen's Park     Ontario Provincial Government  43.662301
#
#    Longitude
# 0 -79.329656
# 1 -79.315572
# 2 -79.360636
# 3 -79.464763
# 4 -79.389494

# %% [markdown]
# # Section 3

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#%pip install folium
import folium # map rendering library

#%pip install geopy
from geopy.geocoders import Nominatim

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
address = 'Toronto, Canada'

geolocator = Nominatim(user_agent="ca_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %%
neighborhoods = data
map_newyork = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhoods['Latitude'], neighborhoods['Longitude'], neighborhoods['Borough'], neighborhoods['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork)  
    
map_newyork
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_6f8b4b9e83e04e2fa4b3b470084565d6%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_6f8b4b9e83e04e2fa4b3b470084565d6%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_6f8b4b9e83e04e2fa4b3b470084565d6%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_6f8b4b9e83e04e2fa4b3b470084565d6%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
CLIENT_ID = 'HK3CTO3E2IPWHPOYBXCZL12C3HIO53SKOSJOF0EMZNVQPFXU' # your Foursquare ID
CLIENT_SECRET = 'EAXJW0NG5H1LWNOHBKSG3K3J0NYDO3O4HRHHYEVN5L04B5LU' # your Foursquare Secret
ACCESS_TOKEN = '3HF5FFVZC42ODXNBZYJDXKZSTBCH3OMRG1JOZ25OOAWYLZDH'
VERSION = '20180605' # Foursquare API version
LIMIT = 100
radius = 500

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
# looks at what are the nearby venues
toronto_nearby = getNearbyVenues(neighborhoods['Neighborhood'],neighborhoods['Latitude'], neighborhoods['Longitude'])
# Out:
# Parkwoods
# Victoria Village
# Regent Park, Harbourfront
# Lawrence Manor, Lawrence Heights
# Ontario Provincial Government
# Islington Avenue
# Malvern, Rouge
# Don Mills North
# Parkview Hill, Woodbine Gardens
# Garden District, Ryerson
# Glencairn
# West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale
# Rouge Hill, Port Union, Highland Creek
# Don Mills South
# Woodbine Heights
# St. James Town
# Humewood-Cedarvale
# Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood
# Guildwood, Morningside, West Hill
# The Beaches
# Berczy Park
# Caledonia-Fairbanks
# Woburn
# Leaside
# Central Bay Street
# Christie
# Cedarbrae
# Hillcrest Village
# Bathurst Manor, Wilson Heights, Downsview North
# Thorncliffe Park
# Richmond, Adelaide, King
# Dufferin, Dovercourt Village
# Scarborough Village
# Fairview, Henry Farm, Oriole
# Northwood Park, York University
# The Danforth  East
# Harbourfront East, Union Station, Toronto Islands
# Little Portugal, Trinity
# Kennedy Park, Ionview, East Birchmount Park
# Bayview Village
# Downsview East
# The Danforth West, Riverdale
# Toronto Dominion Centre, Design Exchange
# Brockton, Parkdale Village, Exhibition Place
# Golden Mile, Clairlea, Oakridge
# York Mills, Silver Hills
# Downsview West
# India Bazaar, The Beaches West
# Commerce Court, Victoria Hotel
# North Park, Maple Leaf Park, Upwood Park
# Humber Summit
# Cliffside, Cliffcrest, Scarborough Village West
# Willowdale, Newtonbrook
# Downsview Central
# Studio District
# Bedford Park, Lawrence Manor East
# Del Ray, Mount Dennis, Keelsdale and Silverthorn
# Humberlea, Emery
# Birch Cliff, Cliffside West
# Willowdale South
# Downsview Northwest
# Lawrence Park
# Roselawn
# Runnymede, The Junction North
# Weston
# Dorset Park, Wexford Heights, Scarborough Town Centre
# York Mills West
# Davisville North
# Forest Hill North & West
# High Park, The Junction South
# Westmount
# Wexford, Maryvale
# Willowdale West
# North Toronto West
# The Annex, North Midtown, Yorkville
# Parkdale, Roncesvalles
# Enclave of L4W
# Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens
# Agincourt
# Davisville
# University of Toronto, Harbord
# Runnymede, Swansea
# Clarks Corners, Tam O'Shanter, Sullivan
# Moore Park, Summerhill East
# Kensington Market, Chinatown, Grange Park
# Milliken, Agincourt North, Steeles East, L'Amoreaux East
# Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# New Toronto, Mimico South, Humber Bay Shores
# South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens
# Steeles West, L'Amoreaux West
# Rosedale
# Enclave of M5E
# Alderwood, Long Branch
# Clairville, Humberwood, Woodbine Downs, West Humber, Kipling Heights, Rexdale, Elms, Tandridge, Old Rexdale
# Upper Rouge
# St. James Town, Cabbagetown
# First Canadian Place, Underground city
# The Kingsway, Montgomery Road, Old Mill North
# Church and Wellesley
# Enclave of M4L
# Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East
# Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West

# %%
# one hot
toronto_venues = toronto_nearby
# Lets analyze the dataframes
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]


# Lets check the onehot dataframe
toronto_onehot.tail()
# Out:
#       Yoga Studio  Accessories Store  Airport  Airport Food Court  \
# 2154            0                  0        0                   0
# 2155            0                  0        0                   0
# 2156            0                  0        0                   0
# 2157            0                  0        0                   0
# 2158            0                  0        0                   0
#
#       Airport Gate  Airport Lounge  Airport Service  Airport Terminal  \
# 2154             0               0                0                 0
# 2155             0               0                0                 0
# 2156             0               0                0                 0
# 2157             0               0                0                 0
# 2158             0               0                0                 0
#
#       American Restaurant  Antique Shop  Aquarium  Arepa Restaurant  \
# 2154                    0             0         0                 0
# 2155                    0             0         0                 0
# 2156                    0             0         0                 0
# 2157                    0             0         0                 0
# 2158                    0             0         0                 0
#
#       Art Gallery  Art Museum  Arts & Crafts Store  Asian Restaurant  \
# 2154            0           0                    0                 0
# 2155            0           0                    0                 0
# 2156            0           0                    0                 0
# 2157            0           0                    0                 0
# 2158            0           0                    0                 0
#
#       Athletics & Sports  Auto Garage  Auto Workshop  BBQ Joint  Baby Store  \
# 2154                   0            0              0          0           0
# 2155                   0            0              0          0           0
# 2156                   0            0              0          0           0
# 2157                   0            0              0          0           0
# 2158                   0            0              0          0           0
#
#       Bagel Shop  Bakery  Bank  Bar  Baseball Field  Baseball Stadium  \
# 2154           0       0     0    0               0                 0
# 2155           0       0     0    0               0                 0
# 2156           0       0     0    0               0                 0
# 2157           0       0     0    0               0                 0
# 2158           0       0     0    0               0                 0
#
#       Basketball Stadium  Beach  Bed & Breakfast  Beer Bar  Beer Store  \
# 2154                   0      0                0         0           0
# 2155                   0      0                0         0           0
# 2156                   0      0                0         0           0
# 2157                   0      0                0         0           0
# 2158                   0      0                0         0           0
#
#       Belgian Restaurant  Bike Shop  Bistro  Board Shop  Boat or Ferry  \
# 2154                   0          0       0           0              0
# 2155                   0          0       0           0              0
# 2156                   0          0       0           0              0
# 2157                   0          0       0           0              0
# 2158                   0          0       0           0              0
#
#       Bookstore  Boutique  Brazilian Restaurant  Breakfast Spot  Brewery  \
# 2154          0         0                     0               0        0
# 2155          0         0                     0               0        0
# 2156          0         0                     0               0        0
# 2157          0         0                     0               0        0
# 2158          0         0                     0               0        0
#
#       Bridal Shop  Bubble Tea Shop  Building  Burger Joint  Burrito Place  \
# 2154            0                0         0             0              0
# 2155            0                0         0             0              0
# 2156            0                0         0             0              0
# 2157            0                0         0             0              0
# 2158            0                0         0             0              0
#
#       Bus Line  Bus Station  Bus Stop  Business Service  Butcher  Café  \
# 2154         0            0         0                 0        0     0
# 2155         0            0         0                 0        0     0
# 2156         0            0         0                 0        0     0
# 2157         0            0         0                 0        0     0
("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
#                         venue  freq
# 0                      Lounge  0.33
# 1   Latin American Restaurant  0.33
# 2              Breakfast Spot  0.33
# 3               Metro Station  0.00
# 4  Modern European Restaurant  0.00
#
#
#             venue  freq
# 0     Pizza Place  0.22
# 1      Playground  0.11
# 2  Sandwich Place  0.11
# 3             Pub  0.11
# 4     Coffee Shop  0.11
#
#
#                  venue  freq
# 0          Coffee Shop  0.08
# 1                 Bank  0.08
# 2    Health Food Store  0.04
# 3       Sandwich Place  0.04
# 4  Fried Chicken Joint  0.04
#
#
#                  venue  freq
# 0                 Café  0.25
# 1   Chinese Restaurant  0.25
# 2                 Bank  0.25
# 3  Japanese Restaurant  0.25
# 4       Medical Center  0.00
#
#
#                 venue  freq
# 0      Sandwich Place  0.08
# 1  Italian Restaurant  0.08
# 2         Coffee Shop  0.08
# 3            Boutique  0.04
# 4    Toy / Game Store  0.04
#
#
#             venue  freq
# 0     Coffee Shop  0.07
# 1    Cocktail Bar  0.05
# 2          Bakery  0.05
# 3      Restaurant  0.03
# 4  Farmers Market  0.03
#
#
#                    venue  freq
# 0        College Stadium   0.2
# 1           Skating Rink   0.2
# 2                   Café   0.2
# 3  General Entertainment   0.2
# 4                   Farm   0.2
#
#
#             venue  freq
# 0            Café  0.12
# 1     Coffee Shop  0.08
# 2  Breakfast Spot  0.08
# 3          Bakery  0.08
# 4       Nightclub  0.04
#
#
#               venue  freq
# 0   Airport Service  0.20
# 1    Airport Lounge  0.13
# 2             Plane  0.07
# 3   Harbor / Marina  0.07
# 4  Sculpture Garden  0.07
#
#
#                         venue  freq
# 0                        Park  0.50
# 1               Women's Store  0.25
# 2                        Pool  0.25
# 3                 Men's Store  0.00
# 4  Modern European Restaurant  0.00
#
#
#                   venue  freq
# 0                  Bank  0.12
# 1      Hakka Restaurant  0.12
# 2  Caribbean Restaurant  0.12
# 3       Thai Restaurant  0.12
# 4           Gas Station  0.12
#
#
#             venue  freq
# 0     Coffee Shop  0.17
# 1  Sandwich Place  0.07
# 2            Café  0.07
# 3      Restaurant  0.04
# 4    Burger Joint  0.03
#
#
#            venue  freq
# 0  Grocery Store  0.27
# 1           Café  0.20
# 2           Park  0.13
# 3    Coffee Shop  0.07
# 4     Baby Store  0.07
#
#
#                  venue  freq
# 0          Coffee Shop  0.09
# 1  Japanese Restaurant  0.08
# 2     Sushi Restaurant  0.06
# 3              Gay Bar  0.05
# 4           Restaurant  0.04
#
#
#                  venue  freq
# 0           Truck Stop  0.25
# 1            Drugstore  0.25
# 2  Rental Car Location  0.25
# 3                  Bar  0.25
# 4    Mobile Phone Shop  0.00
#
#
#                   venue  freq
# 0           Pizza Place  0.13
# 1  Fast Food Restaurant  0.13
# 2           Gas Station  0.07
# 3     Convenience Store  0.07
# 4          Noodle House  0.07
#
#
#                              venue  freq
# 0                            Motel   0.5
# 1              American Restaurant   0.5
# 2                    Metro Station   0.0
# 3  Molecular Gastronomy Restaurant   0.0
# 4       Modern European Restaurant   0.0
#
#
#          venue  freq
# 0  Coffee Shop  0.13
# 1         Café  0.07
# 2   Restaurant  0.07
# 3        Hotel  0.06
# 4          Gym  0.04
#
#
#                 venue  freq
# 0         Pizza Place  0.09
# 1        Dessert Shop  0.09
# 2      Sandwich Place  0.09
# 3     Thai Restaurant  0.06
# 4  Italian Restaurant  0.06
#
#
#                   venue  freq
# 0  Gym / Fitness Center   0.1
# 1        Breakfast Spot   0.1
# 2                 Hotel   0.1
# 3     Food & Drink Shop   0.1
# 4      Department Store   0.1
#
#
#                   venue  freq
# 0  Fast Food Restaurant  0.50
# 1        Discount Store  0.25
# 2        Sandwich Place  0.25
# 3           Men's Store  0.00
# 4     Mobile Phone Shop  0.00
#
#
#                   venue  freq
# 0                  Café   0.2
# 1   Japanese Restaurant   0.2
# 2                   Gym   0.2
# 3  Caribbean Restaurant   0.2
# 4    Athletics & Sports   0.2
#
#
#                  venue  freq
# 0          Coffee Shop  0.10
# 1                  Gym  0.10
# 2           Restaurant  0.10
# 3  Sporting Goods Shop  0.05
# 4   Dim Sum Restaurant  0.05
#
#
#                     venue  freq
# 0       Indian Restaurant  0.22
# 1             Gaming Cafe  0.11
# 2   Vietnamese Restaurant  0.11
# 3  Thrift / Vintage Store  0.11
# 4      Chinese Restaurant  0.11
#
#
#               venue  freq
# 0  Business Service  0.25
# 1        Food Truck  0.25
# 2    Baseball Field  0.25
# 3      Home Service  0.25
# 4       Yoga Studio  0.00
#
#
#                         venue  freq
# 0                     Airport   0.5
# 1                        Park   0.5
# 2                 Yoga Studio   0.0
# 3                 Men's Store   0.0
# 4  Modern European Restaurant   0.0
#
#
#                 venue  freq
# 0        Liquor Store  0.25
# 1       Grocery Store  0.25
# 2  Athletics & Sports  0.25
# 3         Coffee Shop  0.25
# 4         Yoga Studio  0.00
#
#
#            venue  freq
# 0  Grocery Store  0.33
# 1           Park  0.17
# 2           Bank  0.17
# 3          Hotel  0.17
# 4  Shopping Mall  0.17
#
#
#          venue  freq
# 0     Pharmacy  0.14
# 1       Bakery  0.14
# 2         Park  0.07
# 3  Music Venue  0.07
# 4         Café  0.07
#
#
#                  venue  freq
# 0          Coffee Shop  0.23
# 1                Hotel  0.15
# 2  Fried Chicken Joint  0.08
# 3                  Gym  0.08
# 4         Intersection  0.08
#
#
#                 venue  freq
# 0  Light Rail Station  0.11
# 1         Yoga Studio  0.06
# 2       Auto Workshop  0.06
# 3                 Spa  0.06
# 4          Skate Park  0.06
#
#
#                 venue  freq
# 0         Coffee Shop  0.11
# 1  Italian Restaurant  0.04
# 2  Seafood Restaurant  0.04
# 3        Cocktail Bar  0.03
# 4               Hotel  0.03
#
#
#           venue  freq
# 0      Pharmacy  0.12
# 1   Coffee Shop  0.12
# 2  Liquor Store  0.12
# 3    Beer Store  0.12
# 4          Café  0.12
#
#
#                   venue  freq
# 0        Clothing Store  0.13
# 1           Coffee Shop  0.07
# 2  Fast Food Restaurant  0.06
# 3            Restaurant  0.04
# 4   Japanese Restaurant  0.03
#
#
#          venue  freq
# 0  Coffee Shop  0.11
# 1         Café  0.07
# 2        Hotel  0.06
# 3          Gym  0.04
# 4   Restaurant  0.04
#
#
#               venue  freq
# 0              Park   0.2
# 1     Jewelry Store   0.2
# 2  Sushi Restaurant   0.2
# 3          Bus Line   0.2
# 4             Trail   0.2
#
#
#                        venue  freq
# 0                Coffee Shop  0.10
# 1             Clothing Store  0.09
# 2  Middle Eastern Restaurant  0.03
# 3             Cosmetics Shop  0.03
# 4        Japanese Restaurant  0.03
#
#
#                  venue  freq
# 0          Pizza Place  0.25
# 1  Japanese Restaurant  0.25
# 2                 Park  0.25
# 3               Bakery  0.25
# 4          Yoga Studio  0.00
#
#
#             venue  freq
# 0          Bakery  0.29
# 1    Intersection  0.14
# 2            Park  0.14
# 3  Ice Cream Shop  0.14
# 4     Bus Station  0.14
#
#
#                 venue  freq
# 0  Mexican Restaurant  0.11
# 1        Intersection  0.11
# 2      Breakfast Spot  0.11
# 3      Medical Center  0.11
# 4   Electronics Store  0.11
#
#
#          venue  freq
# 0  Coffee Shop  0.12
# 1     Aquarium  0.05
# 2        Hotel  0.04
# 3         Café  0.04
# 4   Restaurant  0.03
#
#
#                 venue  freq
# 0  Mexican Restaurant  0.08
# 1                Café  0.08
# 2     Thai Restaurant  0.08
# 3              Bakery  0.04
# 4      Discount Store  0.04
#
#
#                       venue  freq
# 0  Mediterranean Restaurant   0.2
# 1      Fast Food Restaurant   0.2
# 2               Golf Course   0.2
# 3                      Pool   0.2
# 4                   Dog Run   0.2
#
#
#                     venue  freq
# 0             Pizza Place  0.33
# 1            Home Service  0.33
# 2  Furniture / Home Store  0.33
# 3                    Park  0.00
# 4    Other Great Outdoors  0.00
#
#
#                         venue  freq
# 0              Baseball Field   1.0
# 1                 Yoga Studio   0.0
# 2               Metro Station   0.0
# 3  Modern European Restaurant   0.0
# 4           Mobile Phone Shop   0.0
#
#
#                         venue  freq
# 0                Tennis Court  0.25
# 1                       Trail  0.25
# 2                       Field  0.25
# 3                Hockey Arena  0.25
# 4  Modern European Restaurant  0.00
#
#
#               venue  freq
# 0              Park  0.10
# 1    Ice Cream Shop  0.05
# 2        Board Shop  0.05
# 3  Sushi Restaurant  0.05
# 4        Steakhouse  0.05
#
#
#               venue  freq
# 0    Discount Store   0.2
# 1  Department Store   0.2
# 2       Bus Station   0.2
# 3        Hobby Shop   0.2
# 4       Coffee Shop   0.2
#
#
#                            venue  freq
# 0                           Café  0.08
# 1                         Bakery  0.05
# 2          Vietnamese Restaurant  0.05
# 3  Vegetarian / Vegan Restaurant  0.05
# 4                   Burger Joint  0.03
#
#
#                 venue  freq
# 0         Pizza Place  0.25
# 1      Sandwich Place  0.25
# 2                Park  0.25
# 3            Bus Line  0.25
# 4  Mexican Restaurant  0.00
#
#
#                     venue  freq
# 0          Clothing Store  0.38
# 1  Furniture / Home Store  0.23
# 2   Vietnamese Restaurant  0.08
# 3      Miscellaneous Shop  0.08
# 4             Coffee Shop  0.08
#
#
#               venue  freq
# 0  Business Service  0.25
# 1              Park  0.25
# 2          Bus Line  0.25
# 3       Swim School  0.25
# 4       Yoga Studio  0.00
#
#
#                  venue  freq
# 0          Coffee Shop  0.10
# 1  Sporting Goods Shop  0.10
# 2                 Bank  0.06
# 3         Burger Joint  0.06
# 4       Breakfast Spot  0.03
#
#
#                    venue  freq
# 0                    Bar  0.07
# 1            Men's Store  0.07
# 2       Asian Restaurant  0.05
# 3                  Diner  0.05
# 4  Vietnamese Restaurant  0.05
#
#
#                         venue  freq
# 0        Fast Food Restaurant   1.0
# 1                 Yoga Studio   0.0
# 2                 Men's Store   0.0
# 3  Modern European Restaurant   0.0
# 4           Mobile Phone Shop   0.0
#
#
#               venue  freq
# 0              Park  0.25
# 1        Playground  0.25
# 2  Sculpture Garden  0.25
# 3      Intersection  0.25
# 4       Yoga Studio  0.00
#
#
#             venue  freq
# 0  Hardware Store  0.07
# 1  Discount Store  0.07
# 2     Social Club  0.07
# 3    Burger Joint  0.07
# 4     Flower Shop  0.07
#
#
#                       venue  freq
# 0                      Park   1.0
# 1               Yoga Studio   0.0
# 2  Mediterranean Restaurant   0.0
# 3         Mobile Phone Shop   0.0
# 4        Miscellaneous Shop   0.0
#                   venue  freq
# 0  Fast Food Restaurant  0.08
# 1                Bakery  0.08
# 2           Pizza Place  0.08
# 3           Coffee Shop  0.08
# 4            Restaurant  0.08
#
#
#                         venue  freq
# 0                        Park  0.33
# 1                      Bakery  0.33
# 2  Construction & Landscaping  0.33
# 3                 Yoga Studio  0.00
# 4                 Men's Store  0.00
#
#
#             venue  freq
# 0  Clothing Store  0.18
# 1     Coffee Shop  0.09
# 2     Yoga Studio  0.05
# 3   Metro Station  0.05
# 4           Diner  0.05
#
#
#                   venue  freq
# 0        Massage Studio   0.2
# 1  Caribbean Restaurant   0.2
# 2           Coffee Shop   0.2
# 3                   Bar   0.2
# 4    Miscellaneous Shop   0.2
#
#
#                         venue  freq
# 0              Baseball Field   1.0
# 1                 Yoga Studio   0.0
# 2               Metro Station   0.0
# 3  Modern European Restaurant   0.0
# 4           Mobile Phone Shop   0.0
#
#
#               venue  freq
# 0       Coffee Shop  0.24
# 1  Sushi Restaurant  0.06
# 2              Café  0.06
# 3             Diner  0.06
# 4       Yoga Studio  0.03
#
#
#                 venue  freq
# 0           Gift Shop  0.14
# 1      Breakfast Spot  0.14
# 2         Coffee Shop  0.07
# 3       Movie Theater  0.07
# 4  Italian Restaurant  0.07
#
#
#                   venue  freq
# 0           Pizza Place  0.18
# 1  Gym / Fitness Center  0.09
# 2             Gastropub  0.09
# 3             Pet Store  0.09
# 4        Breakfast Spot  0.09
#
#
#                   venue  freq
# 0     Food & Drink Shop  0.33
# 1  Fast Food Restaurant  0.33
# 2                  Park  0.33
# 3           Yoga Studio  0.00
# 4     Mobile Phone Shop  0.00
#
#
#          venue  freq
# 0  Coffee Shop  0.18
# 1       Bakery  0.07
# 2         Café  0.07
# 3          Pub  0.07
# 4         Park  0.07
#
#
#             venue  freq
# 0     Coffee Shop  0.07
# 1            Café  0.05
# 2           Hotel  0.04
# 3  Clothing Store  0.04
# 4             Gym  0.04
#
#
#                venue  freq
# 0               Park  0.50
# 1              Trail  0.25
# 2         Playground  0.25
# 3        Yoga Studio  0.00
# 4  Mobile Phone Shop  0.00
#
#
#                              venue  freq
# 0                     Home Service  0.33
# 1                   Ice Cream Shop  0.33
# 2                           Garden  0.33
# 3               Mexican Restaurant  0.00
# 4  Molecular Gastronomy Restaurant  0.00
#
#
#                              venue  freq
# 0                     Home Service   0.5
# 1                              Bar   0.5
# 2              Moroccan Restaurant   0.0
# 3  Molecular Gastronomy Restaurant   0.0
# 4       Modern European Restaurant   0.0
#
#
#                 venue  freq
# 0         Coffee Shop  0.11
# 1    Sushi Restaurant  0.08
# 2                Café  0.08
# 3                 Pub  0.05
# 4  Italian Restaurant  0.05
#
#
#                venue  freq
# 0        Pizza Place  0.25
# 1      Grocery Store  0.25
# 2           Bus Line  0.25
# 3  Convenience Store  0.25
# 4      Metro Station  0.00
#
#
#                         venue  freq
# 0               Grocery Store   0.5
# 1                  Playground   0.5
# 2                 Yoga Studio   0.0
# 3                 Men's Store   0.0
# 4  Modern European Restaurant   0.0
#
#
#             venue  freq
# 0   Grocery Store   0.2
# 1        Pharmacy   0.1
# 2    Liquor Store   0.1
# 3  Sandwich Place   0.1
# 4     Coffee Shop   0.1
#
#
#                 venue  freq
# 0                Café  0.07
# 1         Coffee Shop  0.07
# 2      Cosmetics Shop  0.03
# 3  Italian Restaurant  0.03
# 4      Clothing Store  0.03
#
#
#          venue  freq
# 0         Café  0.07
# 1  Coffee Shop  0.07
# 2       Bakery  0.07
# 3          Pub  0.04
# 4  Pizza Place  0.04
#
#
#                   venue  freq
# 0  Fast Food Restaurant  0.17
# 1          Intersection  0.08
# 2           Coffee Shop  0.08
# 3    Chinese Restaurant  0.08
# 4        Sandwich Place  0.08
#
#
#          venue  freq
# 0  Coffee Shop  0.08
# 1      Brewery  0.06
# 2    Gastropub  0.06
# 3         Café  0.06
# 4       Bakery  0.06
#
#
#                  venue  freq
# 0          Coffee Shop  0.15
# 1  American Restaurant  0.08
# 2  Fried Chicken Joint  0.08
# 3     Sushi Restaurant  0.08
# 4           Restaurant  0.08
#
#
#             venue  freq
# 0            Café  0.14
# 1  Sandwich Place  0.14
# 2     Coffee Shop  0.10
# 3             Pub  0.05
# 4     Cheese Shop  0.05
#
#
#                         venue  freq
# 0                         Pub  0.25
# 1           Health Food Store  0.25
# 2                       Trail  0.25
# 3                 Yoga Studio  0.00
# 4  Modern European Restaurant  0.00
#
#
#                 venue  freq
# 0                Park  0.50
# 1   Convenience Store  0.25
# 2        Intersection  0.25
# 3         Yoga Studio  0.00
# 4  Mexican Restaurant  0.00
#
#
#                     venue  freq
# 0        Greek Restaurant  0.17
# 1             Coffee Shop  0.07
# 2          Ice Cream Shop  0.05
# 3                    Café  0.05
# 4  Furniture / Home Store  0.05
#
#
#                         venue  freq
# 0                       River   0.5
# 1                        Pool   0.5
# 2                 Yoga Studio   0.0
# 3               Metro Station   0.0
# 4  Modern European Restaurant   0.0
#
#
#                venue  freq
# 0     Sandwich Place  0.10
# 1  Indian Restaurant  0.10
# 2        Yoga Studio  0.05
# 3               Park  0.05
# 4         Restaurant  0.05
#
#
#                 venue  freq
# 0         Coffee Shop  0.12
# 1               Hotel  0.08
# 2                Café  0.06
# 3          Restaurant  0.04
# 4  Seafood Restaurant  0.03
#
#
#             venue  freq
# 0            Café  0.15
# 1       Bookstore  0.06
# 2  Sandwich Place  0.06
# 3             Bar  0.06
# 4          Bakery  0.06
#
#
#                    venue  freq
# 0            Pizza Place   0.2
# 1            Coffee Shop   0.2
# 2  Portuguese Restaurant   0.2
# 3           Hockey Arena   0.2
# 4           Intersection   0.2
#
#
#                         venue  freq
# 0                      Bakery   1.0
# 1                 Yoga Studio   0.0
# 2               Metro Station   0.0
# 3  Modern European Restaurant   0.0
# 4           Mobile Phone Shop   0.0
#
#
#             venue  freq
# 0     Pizza Place  0.25
# 1  Discount Store  0.12
# 2      Playground  0.12
# 3    Intersection  0.12
# 4  Sandwich Place  0.12
#
#
#                       venue  freq
# 0                      Park   1.0
# 1               Yoga Studio   0.0
# 2  Mediterranean Restaurant   0.0
# 3         Mobile Phone Shop   0.0
# 4        Miscellaneous Shop   0.0
#
#
#                              venue  freq
# 0        Middle Eastern Restaurant   0.4
# 1                      Auto Garage   0.2
# 2                   Sandwich Place   0.2
# 3                           Bakery   0.2
# 4  Molecular Gastronomy Restaurant   0.0
#
#
#                  venue  freq
# 0     Ramen Restaurant  0.09
# 1          Coffee Shop  0.06
# 2  Japanese Restaurant  0.06
# 3        Shopping Mall  0.06
# 4          Pizza Place  0.06
#
#
#             venue  freq
# 0        Pharmacy  0.14
# 1     Coffee Shop  0.14
# 2         Butcher  0.14
# 3     Supermarket  0.14
# 4  Discount Store  0.14
#
#
#                       venue  freq
# 0                      Park   1.0
# 1               Yoga Studio   0.0
# 2  Mediterranean Restaurant   0.0
# 3         Mobile Phone Shop   0.0
# 4        Miscellaneous Shop   0.0
#
#
#                              venue  freq
# 0                      Coffee Shop  0.50
# 1            Korean BBQ Restaurant  0.25
# 2               Mexican Restaurant  0.25
# 3                    Metro Station  0.00
# 4  Molecular Gastronomy Restaurant  0.00
#
#
#                 venue  freq
# 0         Curling Ice  0.11
# 1                Park  0.11
# 2                 Spa  0.11
# 3        Intersection  0.11
# 4  Athletics & Sports  0.11
#
#
#                         venue  freq
# 0                        Park   0.5
# 1           Convenience Store   0.5
# 2                 Yoga Studio   0.0
# 3                 Men's Store   0.0
# 4  Modern European Restaurant   0.0
#
#
#                       venue  freq
# 0                      Park   1.0
# 1               Yoga Studio   0.0
# 2  Mediterranean Restaurant   0.0
# 3         Mobile Phone Shop   0.0
# 4        Miscellaneous Shop   0.0

# %%
#lets sort the venues in descending order and display the top 10 venues for each neighborhood.
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]
	
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# %%
# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)
    
#Lets preview our sorted venues dataframe
neighborhoods_venues_sorted.head()
# Out:
#                                       Neighborhood 1st Most Common Venue  \
# 0                                        Agincourt                Lounge
# 1                           Alderwood, Long Branch           Pizza Place
# 2  Bathurst Manor, Wilson Heights, Downsview North           Coffee Shop
# 3                                  Bayview Village                  Café
# 4                Bedford Park, Lawrence Manor East        Sandwich Place
#
#        2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0  Latin American Restaurant        Breakfast Spot         Metro Station
# 1                 Playground        Sandwich Place                   Pub
# 2                       Bank     Health Food Store        Sandwich Place
# 3         Chinese Restaurant                  Bank   Japanese Restaurant
# 4         Italian Restaurant           Coffee Shop              Boutique
#
#         5th Most Common Venue     6th Most Common Venue 7th Most Common Venue  \
# 0  Modern European Restaurant         Mobile Phone Shop    Miscellaneous Shop
# 1                 Coffee Shop                      Pool              Pharmacy
# 2         Fried Chicken Joint          Sushi Restaurant           Supermarket
# 3              Medical Center  Mediterranean Restaurant           Men's Store
# 4            Toy / Game Store                Restaurant      Sushi Restaurant
#
#        8th Most Common Venue 9th Most Common Venue     10th Most Common Venue
# 0  Middle Eastern Restaurant    Mexican Restaurant   Mediterranean Restaurant
# 1                        Gym        Massage Studio             Medical Center
# 2                Bridal Shop         Shopping Mall  Middle Eastern Restaurant
# 3              Metro Station    Mexican Restaurant        Moroccan Restaurant
# 4                  Juice Bar          Liquor Store                        Pub

# %%
#Run k-means to cluster the neighborhood into 7 clusters.

# set number of clusters
kclusters = 7

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
print(kmeans.labels_[0:10])
# Out:
# [0 0 0 0 0 0 0 0 0 3]

# %%
#Let's create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.
# add clustering labels
toronto_data = neighborhoods

neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = toronto_data

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')
toronto_merged = toronto_merged.dropna() #dropping the null values in columns as they have little/no effect on our cluster

toronto_merged.head()
# Out:
#   PostalCode           Borough                      Neighborhood   Latitude  \
# 0        M3A        North York                         Parkwoods  43.753259
# 1        M4A        North York                  Victoria Village  43.725882
# 2        M5A  Downtown Toronto         Regent Park, Harbourfront  43.654260
# 3        M6A        North York  Lawrence Manor, Lawrence Heights  43.718518
# 4        M7A      Queen's Park     Ontario Provincial Government  43.662301
#
#    Longitude  Cluster Labels 1st Most Common Venue   2nd Most Common Venue  \
# 0 -79.329656             0.0     Food & Drink Shop    Fast Food Restaurant
# 1 -79.315572             0.0           Pizza Place             Coffee Shop
# 2 -79.360636             0.0           Coffee Shop                  Bakery
# 3 -79.464763             0.0        Clothing Store  Furniture / Home Store
# 4 -79.389494             0.0           Coffee Shop        Sushi Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0                   Park           Yoga Studio     Mobile Phone Shop
# 1  Portuguese Restaurant          Hockey Arena          Intersection
# 2                   Café                   Pub                  Park
# 3  Vietnamese Restaurant    Miscellaneous Shop           Coffee Shop
# 4                   Café                 Diner           Yoga Studio
#
#   6th Most Common Venue      7th Most Common Venue 8th Most Common Venue  \
# 0    Miscellaneous Shop  Middle Eastern Restaurant    Mexican Restaurant
# 1  Other Great Outdoors        Moroccan Restaurant   Martial Arts School
# 2               Theater             Farmers Market        Breakfast Spot
# 3              Boutique          Accessories Store        Massage Studio
# 4     College Cafeteria                   Beer Bar         Smoothie Shop
#
#   9th Most Common Venue    10th Most Common Venue
# 0         Metro Station               Men's Store
# 1        Massage Studio            Medical Center
# 2        Chocolate Shop              Dessert Shop
# 3        Medical Center  Mediterranean Restaurant
# 4         Burrito Place            Sandwich Place

# %%
#Now lets visualize the clusters

# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    #print(cluster)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster)],
        fill=True,
        fill_color=rainbow[int(cluster)],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_8c2274a06502405db20a7efee438198c%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_8c2274a06502405db20a7efee438198c%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_8c2274a06502405db20a7efee438198c%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_8c2274a06502405db20a7efee438198c%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
# get potential places with top 3 for Restaurant
potential_places = toronto_merged.loc[toronto_merged['1st Most Common Venue'].str.startswith('Restaurant') | toronto_merged['2nd Most Common Venue'].str.startswith('Restaurant') | toronto_merged['3rd Most Common Venue'].str.startswith('Restaurant')]
potential_places
# Out:
#    PostalCode           Borough                    Neighborhood   Latitude  \
# 13        M3C        North York                 Don Mills South  43.725900
# 48        M5L  Downtown Toronto  Commerce Court, Victoria Hotel  43.648198
#
#     Longitude  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 13 -79.340923             0.0           Coffee Shop                   Gym
# 48 -79.379817             0.0           Coffee Shop                  Café
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 13            Restaurant   Sporting Goods Shop    Dim Sum Restaurant
# 48            Restaurant                 Hotel                   Gym
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 13             Bike Shop      Asian Restaurant        Discount Store
# 48    Seafood Restaurant         Deli / Bodega   Japanese Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 13      Sushi Restaurant            Art Gallery
# 48                Bakery    American Restaurant

# %%
#Now lets visualize the neighbourhood for shotlist
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(potential_places['Latitude'], potential_places['Longitude'], potential_places['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    #print(cluster)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster)],
        fill=True,
        fill_color=rainbow[int(cluster)],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_b0af31138d24454ca6f92a4589644bb7%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_b0af31138d24454ca6f92a4589644bb7%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_b0af31138d24454ca6f92a4589644bb7%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_b0af31138d24454ca6f92a4589644bb7%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
#download demographic data from https://open.toronto.ca/dataset/neighbourhood-profiles/

population = pd.read_csv('neighbourhood-profiles-2016.csv')

potential_places = potential_places.join(population.set_index('Neighborhood'), on='Neighborhood')
potential_places = potential_places.dropna() 
potential_places
# Out:
#    PostalCode           Borough                    Neighborhood   Latitude  \
# 13        M3C        North York                 Don Mills South  43.725900
# 48        M5L  Downtown Toronto  Commerce Court, Victoria Hotel  43.648198
#
#     Longitude  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 13 -79.340923             0.0           Coffee Shop                   Gym
# 48 -79.379817             0.0           Coffee Shop                  Café
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 13            Restaurant   Sporting Goods Shop    Dim Sum Restaurant
# 48            Restaurant                 Hotel                   Gym
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 13             Bike Shop      Asian Restaurant        Discount Store
# 48    Seafood Restaurant         Deli / Bodega   Japanese Restaurant
#
#    9th Most Common Venue 10th Most Common Venue density
# 13      Sushi Restaurant            Art Gallery   2,775
# 48                Bakery    American Restaurant   3,710

# %%
potential_places['density_int'] = pd.to_numeric(potential_places['density'].str.replace(',',''))# = int(potential_places['density'])
final_list = potential_places[['Neighborhood','density_int']].sort_values(by = 'density_int', ascending=False, inplace=False)
final_list.head(1)
# Out:
#                       Neighborhood  density_int
# 48  Commerce Court, Victoria Hotel         3710

# %%
final_list = potential_places[1:2]

# %%
#Now lets visualize the neighbourhood for final winner
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=13)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(final_list['Latitude'], final_list['Longitude'], final_list['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    #print(cluster)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster)],
        fill=True,
        fill_color=rainbow[int(cluster)],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_eec2a7a0dbf74203b25b5a577c9a0e38%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_eec2a7a0dbf74203b25b5a577c9a0e38%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_eec2a7a0dbf74203b25b5a577c9a0e38%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_eec2a7a0dbf74203b25b5a577c9a0e38%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...
